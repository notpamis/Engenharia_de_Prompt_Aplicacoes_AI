# %% [markdown]
# <a href="https://colab.research.google.com/github/notpamis/Engenharia_de_Prompt_Aplicacoes_AI/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # aula: programação assistida
# nome: kadidja valéria (turma sextou)

# %%
numeros = [1, 2, 3]
soma = 0
i = 0
while i < len (numeros):
  soma += numeros[i]
  i += 1
print (numeros)
# Out:
# [1, 2, 3]
